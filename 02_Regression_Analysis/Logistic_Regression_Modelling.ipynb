# %% [markdown]
# #**Data Cleaning, Preprocessing and Summary statistics and Visualizations**

# %%
import pandas as pd
df = pd.read_csv('coffee_health.csv')
df
# Out:
#          ID  Age  Gender  Country  Coffee_Intake  Caffeine_mg  Sleep_Hours  \
# 0         1   40    Male  Germany            3.5        328.1          7.5
# 1         2   33    Male  Germany            1.0         94.1          6.2
# 2         3   42    Male   Brazil            5.3        503.7          5.9
# 3         4   53    Male  Germany            2.6        249.2          7.3
# 4         5   32  Female    Spain            3.1        298.0          5.3
# ...     ...  ...     ...      ...            ...          ...          ...
# 9995   9996   50  Female    Japan            2.1        199.8          6.0
# 9996   9997   18  Female       UK            3.4        319.2          5.8
# 9997   9998   26    Male    China            1.6        153.4          7.1
# 9998   9999   40  Female  Finland            3.4        327.1          7.0
# 9999  10000   42  Female   Brazil            2.9        277.5          6.4
#
#      Sleep_Quality   BMI  Heart_Rate Stress_Level  Physical_Activity_Hours  \
# 0             Good  24.9          78          Low                     14.5
# 1             Good  20.0          67          Low                     11.0
# 2             Fair  22.7          59       Medium                     11.2
# 3             Good  24.7          71          Low                      6.6
# 4             Fair  24.1          76       Medium                      8.5
# ...            ...   ...         ...          ...                      ...
# 9995          Fair  30.5          50       Medium                     10.1
# 9996          Fair  19.1          71       Medium                     11.6
# 9997          Good  25.1          66          Low                     13.7
# 9998          Good  19.3          80          Low                      0.1
# 9999          Good  28.1          72          Low                      9.8
#
#      Health_Issues  Occupation  Smoking  Alcohol_Consumption
# 0              NaN       Other        0                    0
# 1              NaN     Service        0                    0
# 2             Mild      Office        0                    0
# 3             Mild       Other        0                    0
# 4             Mild     Student        0                    1
# ...            ...         ...      ...                  ...
# 9995      Moderate  Healthcare        0                    1
# 9996          Mild     Service        0                    0
# 9997           NaN     Student        1                    1
# 9998           NaN     Student        0                    0
# 9999           NaN     Student        1                    0
#
# [10000 rows x 16 columns]

# %% [markdown]
# ##Checking for null values

# %%
df.isnull().sum()
# Out:
# ID                            0
# Age                           0
# Gender                        0
# Country                       0
# Coffee_Intake                 0
# Caffeine_mg                   0
# Sleep_Hours                   0
# Sleep_Quality                 0
# BMI                           0
# Heart_Rate                    0
# Stress_Level                  0
# Physical_Activity_Hours       0
# Health_Issues              5941
# Occupation                    0
# Smoking                       0
# Alcohol_Consumption           0
# dtype: int64

# %% [markdown]
# ##Replacing Null values with Mean in Health Issues column

# %%
df['Health_Issues'].fillna(df['Health_Issues'].mode()[0], inplace=True)
df.head()
# Out:
# /tmp/ipython-input-357722939.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Health_Issues'].fillna(df['Health_Issues'].mode()[0], inplace=True)
#    ID  Age  Gender  Country  Coffee_Intake  Caffeine_mg  Sleep_Hours  \
# 0   1   40    Male  Germany            3.5        328.1          7.5
# 1   2   33    Male  Germany            1.0         94.1          6.2
# 2   3   42    Male   Brazil            5.3        503.7          5.9
# 3   4   53    Male  Germany            2.6        249.2          7.3
# 4   5   32  Female    Spain            3.1        298.0          5.3
#
#   Sleep_Quality   BMI  Heart_Rate Stress_Level  Physical_Activity_Hours  \
# 0          Good  24.9          78          Low                     14.5
# 1          Good  20.0          67          Low                     11.0
# 2          Fair  22.7          59       Medium                     11.2
# 3          Good  24.7          71          Low                      6.6
# 4          Fair  24.1          76       Medium                      8.5
#
#   Health_Issues Occupation  Smoking  Alcohol_Consumption
# 0          Mild      Other        0                    0
# 1          Mild    Service        0                    0
# 2          Mild     Office        0                    0
# 3          Mild      Other        0                    0
# 4          Mild    Student        0                    1

# %% [markdown]
# ##Descriptive Statistics

# %%
df.describe()
# Out:
#                 ID           Age  Coffee_Intake   Caffeine_mg   Sleep_Hours  \
# count  10000.00000  10000.000000   10000.000000  10000.000000  10000.000000
# mean    5000.50000     34.949100       2.509230    238.411010      6.636220
# std     2886.89568     11.160939       1.450248    137.748815      1.222055
# min        1.00000     18.000000       0.000000      0.000000      3.000000
# 25%     2500.75000     26.000000       1.500000    138.750000      5.800000
# 50%     5000.50000     34.000000       2.500000    235.400000      6.600000
# 75%     7500.25000     43.000000       3.500000    332.025000      7.500000
# max    10000.00000     80.000000       8.200000    780.300000     10.000000
#
#                 BMI    Heart_Rate  Physical_Activity_Hours      Smoking  \
# count  10000.000000  10000.000000              10000.00000  10000.00000
# mean      23.986860     70.617800                  7.48704      0.20040
# std        3.906411      9.822951                  4.31518      0.40032
# min       15.000000     50.000000                  0.00000      0.00000
# 25%       21.300000     64.000000                  3.70000      0.00000
# 50%       24.000000     71.000000                  7.50000      0.00000
# 75%       26.600000     77.000000                 11.20000      0.00000
# max       38.200000    109.000000                 15.00000      1.00000
#
#        Alcohol_Consumption
# count         10000.000000
# mean              0.300700
# std               0.458585
# min               0.000000
# 25%               0.000000
# 50%               0.000000
# 75%               1.000000
# max               1.000000

# %% [markdown]
# ##A Descriptive Pivot table

# %%
pivot = df.pivot_table(index=['Country'],
                       values=['Age', 'Smoking', 'BMI', 'Heart_Rate', 'Coffee_Intake'],
                       aggfunc=['mean', 'max', 'min', 'count','sum', 'std'])
print(pivot)
# Out:
#                   mean                                               max  \
#                    Age        BMI Coffee_Intake Heart_Rate   Smoking Age
# Country
# Australia    35.434608  24.049698      2.544266  70.205231  0.195171  64
# Belgium      34.835010  24.233602      2.411670  70.818913  0.173038  67
# Brazil       35.188596  24.008991      2.547588  71.162281  0.182018  70
# Canada       35.068140  24.169797      2.497606  70.869245  0.174954  77
# China        35.214971  23.885029      2.574664  70.234165  0.209213  70
# Finland      34.690196  23.814706      2.477843  71.319608  0.188235  75
# France       35.342685  24.011623      2.528457  69.899800  0.214429  68
# Germany      35.042254  23.584708      2.466398  71.209256  0.187123  70
# India        34.685115  24.187214      2.503435  70.372137  0.221374  80
# Italy        34.732809  23.760904      2.441257  70.420432  0.223969  72
# Japan        34.584222  24.057569      2.533902  69.577825  0.206823  64
# Mexico       34.759834  24.074327      2.449896  71.055901  0.188406  64
# Netherlands  35.301619  24.126316      2.461538  70.087045  0.192308  80
# Norway       34.959847  23.761950      2.588145  70.936902  0.204589  72
# South Korea  35.765625  23.880859      2.461328  70.179688  0.257812  72
# Spain        34.993827  23.968107      2.599794  70.921811  0.176955  73
# Sweden       35.247563  24.008577      2.418129  70.892788  0.235867  73
# Switzerland  34.638000  24.057600      2.540400  70.614000  0.206000  65
# UK           34.358382  24.082081      2.582274  71.003854  0.179191  72
# USA          34.040179  24.022321      2.563393  70.537946  0.185268  69
#
#                                                     ...    sum           \
#               BMI Coffee_Intake Heart_Rate Smoking  ...    Age      BMI
# Country                                             ...
# Australia    37.8           7.8        103       1  ...  17611  11952.7
# Belgium      36.0           7.8        104       1  ...  17313  12044.1
# Brazil       35.1           6.6         99       1  ...  16046  10948.1
# Canada       35.5           7.0         97       1  ...  19042  13124.2
# China        35.8           7.1        100       1  ...  18347  12444.1
# Finland      37.2           6.5         98       1  ...  17692  12145.5
# France       34.8           7.6         97       1  ...  17636  11981.8
# Germany      36.5           7.0         95       1  ...  17416  11721.6
# India        36.0           7.0        101       1  ...  18175  12674.1
# Italy        36.6           7.3        106       1  ...  17679  12094.3
# Japan        36.7           7.6         97       1  ...  16220  11283.0
# Mexico       38.2           6.7        100       1  ...  16789  11627.9
# Netherlands  37.2           8.2        107       1  ...  17439  11918.4
# Norway       34.8           7.6        109       1  ...  18284  12427.5
# South Korea  37.9           7.3         99       1  ...  18312  12227.0
# Spain        36.9           6.5        100       1  ...  17007  11648.5
# Sweden       37.0           7.2         98       1  ...  18082  12316.4
# Switzerland  35.1           6.5         97       1  ...  17319  12028.8
# UK           34.5           7.0         98       1  ...  17832  12498.6
# USA          37.5           7.7        102       1  ...  15250  10762.0
#
#                                                     std            \
#             Coffee_Intake Heart_Rate Smoking        Age       BMI
# Country
# Australia          1264.5      34892      97  11.307124  3.898610
# Belgium            1198.6      35197      86  11.278233  3.807995
# Brazil             1161.7      32450      83  11.340851  3.846189
# Canada             1356.2      38482      95  10.858404  4.005836
# China              1341.4      36592     109  11.235411  3.874409
# Finland            1263.7      36373      96  10.979983  4.039369
# France             1261.7      34880     107  11.173010  3.868873
# Germany            1225.8      35391      93  11.238624  4.005677
# India              1311.8      36875     116  11.582858  3.930317
# Italy              1242.6      35844     114  11.058867  3.787290
# Japan              1188.4      32632      97  10.989887  3.846062
# Mexico             1183.3      34320      91  11.012831  3.932459
# Netherlands        1216.0      34623      95  11.483656  3.981641
# Norway             1353.6      37100     107  11.410333  3.730482
# South Korea        1260.2      35932     132  11.456706  3.930326
# Spain              1263.5      34468      86  10.954920  4.034193
# Sweden             1240.5      36368     121  11.327818  3.902218
# Switzerland        1270.2      35307     103  11.006782  3.819778
# UK                 1340.2      36851      93  10.703024  3.923079
# USA                1148.4      31601      83  10.813373  3.954121
#
#
#             Coffee_Intake Heart_Rate   Smoking
# Country
# Australia        1.467254   9.862468  0.396732
# Belgium          1.415035   9.579643  0.378661
# Brazil           1.430221   9.008908  0.386283
# Canada           1.525011   9.661400  0.380278
# China            1.450402   9.744765  0.407138
# Finland          1.452036   9.889061  0.391284
# France           1.457315   9.811577  0.410837
# Germany          1.431464   9.669356  0.390403
# India            1.443846  10.099357  0.415568
# Italy            1.444657   9.587560  0.417311
# Japan            1.435978   9.928850  0.405460
# Mexico           1.408648   9.674740  0.391441
# Netherlands      1.529248  10.101037  0.394513
# Norway           1.501166  10.304271  0.403787
# South Korea      1.506447   9.818855  0.437858
# Spain            1.406443  10.362206  0.382024
# Sweden           1.478942   9.625924  0.424954
# Switzerland      1.365803   9.528409  0.404836
# UK               1.357773  10.099695  0.383882
# USA              1.479358   9.917936  0.388949
#
# [20 rows x 30 columns]

# %% [markdown]
# ##Visualization Using Plotly and Matplotlib

# %%
import plotly.graph_objects as go
import plotly.express as px
import matplotlib.pyplot as plt

# %% [markdown]
# ###Gender-Based Visualization on the Influence of Coffee to their Health Issues and Stress levels

# %%
plt.figure(figsize=(10, 6), facecolor='y')
X = df['Gender'].value_counts().index
Y = df['Health_Issues'].value_counts().index
Y1= df['Stress_Level'].value_counts().index
plt.bar(X, Y, label='Health Issues', color='c')
plt.bar(X, Y1, bottom= 'Y', label='Stress Levels', color='b')
plt.legend()
plt.xlabel('Gender')
plt.ylabel('Health issues and stress levels')
plt.title('Gender-Based Visualization Health issues and Stress Levels as Influenced by Coffee')
plt.show()

# %% [markdown]
# ### Visualization of Coffee Intake Across Different Countries

# %%
fig = px.area(df,
             x='Country',
             y='Coffee_Intake',
             title='Average Coffee Intake Across Different Countries and it\'s Influence on stress levels',
             color='Stress_Level',
             )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4c6d81c8-5be9-4bda-8d85-1be6c17ea9f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c6d81c8-5be9-4bda-8d85-1be6c17ea9f7")) {                    Plotly.newPlot(                        "4c6d81c8-5be9-4bda-8d85-1be6c17ea9f7",                        [{"fillpattern":{"shape":""},"hovertemplate":"Stress_Level=Low\u003cbr\u003eCountry=%{x}\u003cbr\u003eCoffee_Intake=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Low","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"Low","orientation":"v","showlegend":true,"stackgroup":"1","x":["Germany","Germany","Germany","Mexico","France","UK","Switzerland","Switzerland","Netherlands","Italy","Italy","Spain","Japan","UK","Germany","Italy","France","Mexico","Canada","Australia","USA","Finland","France","Sweden","Brazil","Italy","China","India","Norway","USA","Norway","Finland","Italy","UK","India","China","Netherlands","Japan","China","Finland","France","India","Sweden","Japan","Spain","Japan","Japan","Netherlands","Sweden","Belgium","Canada","Italy","Brazil","Australia","Mexico","Germany","Japan","UK","UK","Australia","Sweden","Australia","Australia","Canada","Brazil","Spain","Netherlands","Canada","Italy","Norway","Germany","South Korea","Italy","France","Netherlands","France","Sweden","UK","Spain","Italy","Norway","Finland","Australia","Spain","Italy","Finland","India","Brazil","South Korea","Mexico","Italy","Canada","India","Japan","Switzerland","Norway","Japan","Japan","UK","China","Spain","Switzerland","Belgium","Spain","Netherlands","Netherlands","Canada","France","UK","Germany","UK","Finland","South Korea","Belgium","China","Norway","France","UK","UK","Germany","China","Netherlands","Japan","France","Italy","Australia","Finland","Italy","UK","Finland","Switzerland","Belgium","Sweden","Italy","USA","Spain","Spain","USA","USA","Norway","Japan","Norway","Mexico","India","China","China","Australia","Norway","Norway","Japan","Sweden","Norway","China","China","Spain","Belgium","Sweden","Switzerland","India","Finland","UK","Sweden","Norway","Italy","South Korea","Brazil","China","Belgium","China","USA","Switzerland","Sweden","Australia","India","Finland","India","Norway","Netherlands","Japan","Mexico","Germany","Spain","Australia","Netherlands","Netherlands","Brazil","Norway","USA","Japan","Mexico","China","Belgium","Brazil","Canada","Germany","South Korea","Switzerland","Australia","Spain","China","Finland","Mexico","Australia","Sweden","France","Australia","Switzerland","India","Brazil","Italy","France","USA","USA","France","Netherlands","South Korea","Australia","Netherlands","Brazil","Belgium","Finland","Canada","South Korea","Australia","Italy","Japan","Canada","Germany","Sweden","Japan","India","Netherlands","Netherlands","UK","Germany","France","Belgium","Germany","India","Brazil","India","Australia","South Korea","UK","China","China","UK","Finland","India","Norway","Norway","USA","France","China","Canada","Switzerland","Switzerland","Belgium","China","Mexico","Brazil","Canada","Netherlands","Netherlands","Spain","France","Japan","Norway","Italy","Sweden","India","UK","Japan","Italy","Australia","Switzerland","India","Germany","Mexico","Germany","Finland","Sweden","Australia","Brazil","Australia","Italy","China","Netherlands","South Korea","Australia","China","USA","Norway","China","Switzerland","India","Netherlands","Mexico","Japan","Canada","China","Netherlands","Netherlands","Australia","Germany","Australia","Brazil","Norway","South Korea","USA","Australia","Brazil","India","Switzerland","Finland","India","Canada","Mexico","Canada","Switzerland","Italy","Finland","Japan","Norway","Spain","UK","India","Norway","Italy","Japan","South Ko ...

# %% [markdown]
# ###Visualizing Physical Active Hours vs Sleeping Hours

# %%
fig = px.bar(df, x="Country",
             y=["Physical_Activity_Hours", "Sleep_Hours"],
             title='Physical Activity vs Sleep Hours Among Different Countries'
             )
fig.update_traces(opacity=1.0)
fig.update_layout(
    yaxis=dict(
        tickformat=".0f"
    )
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c5df7413-33de-48ff-8147-a930fdf1a50c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5df7413-33de-48ff-8147-a930fdf1a50c")) {                    Plotly.newPlot(                        "c5df7413-33de-48ff-8147-a930fdf1a50c",                        [{"alignmentgroup":"True","hovertemplate":"variable=Physical_Activity_Hours\u003cbr\u003eCountry=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Physical_Activity_Hours","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Physical_Activity_Hours","offsetgroup":"Physical_Activity_Hours","orientation":"v","showlegend":true,"textposition":"auto","x":["Germany","Germany","Brazil","Germany","Spain","Mexico","France","Canada","UK","Switzerland","Switzerland","Netherlands","Italy","Italy","Mexico","Spain","China","Japan","UK","Germany","Italy","France","Belgium","UK","Finland","Mexico","Belgium","Australia","Canada","Australia","USA","Finland","France","Sweden","Brazil","China","Italy","China","China","India","Norway","USA","Norway","Finland","Italy","Canada","UK","India","China","Belgium","Netherlands","Japan","China","Finland","France","India","Spain","India","Sweden","Japan","Spain","Japan","Finland","Japan","Netherlands","Sweden","Mexico","Belgium","Canada","Italy","Brazil","Australia","Mexico","Germany","Finland","Japan","Australia","UK","UK","Australia","Sweden","Australia","Australia","Spain","Canada","Brazil","Spain","Netherlands","Canada","Italy","Italy","Norway","Germany","South Korea","Italy","France","Netherlands","France","Sweden","UK","Spain","Italy","India","Norway","Finland","Australia","Belgium","Spain","Norway","Sweden","Italy","Finland","India","Brazil","South Korea","Mexico","Italy","Canada","India","Japan","Sweden","Switzerland","Norway","Sweden","Japan","Japan","Canada","UK","China","UK","China","Canada","Spain","USA","Switzerland","Belgium","Spain","Spain","Netherlands","Netherlands","Canada","France","UK","Germany","Spain","UK","Finland","South Korea","Belgium","China","Australia","Norway","Switzerland","France","Spain","UK","UK","Germany","China","Netherlands","India","Japan","France","Finland","Italy","Australia","Finland","Italy","UK","Spain","Finland","Switzerland","Belgium","Sweden","Italy","USA","Spain","Spain","USA","USA","Norway","Japan","Norway","Mexico","India","China","China","Australia","Mexico","Norway","Norway","Japan","Sweden","Germany","Norway","Switzerland","China","China","Spain","Belgium","Sweden","Switzerland","India","India","Finland","UK","China","Sweden","Norway","India","Italy","South Korea","Brazil","China","Belgium","China","Italy","USA","Switzerland","Sweden","Australia","Finland","India","Brazil","Canada","Finland","India","Norway","Netherlands","Japan","Mexico","Germany","Spain","Australia","UK","Netherlands","Netherlands","Netherlands","Brazil","Sweden","Norway","USA","Japan","Mexico","China","Belgium","Brazil","Canada","Germany","South Korea","Switzerland","Australia","Spain","Mexico","Finland","China","Finland","Belgium","Brazil","UK","Mexico","Brazil","Australia","Sweden","UK","France","Australia","Switzerland","India","Brazil","Italy","Switzerland","USA","France","Belgium","USA","USA","France","Spain","Canada","South Korea","Netherlands","South Korea","India","Australia","Netherlands","Brazil","Belgium","Japan","Sweden","Finland","Canada","Canada","Norway","South Korea","Australia","Italy","Canada","Japan","Canada","Belgium","Australia","Germany","Sweden","Japan","India","Netherlands","India","Sweden","Netherlands","UK","Germany","France","Belgium","Germany","India","Brazil","India","Australia","South Korea","Sweden","UK","China","China","Brazil","Norway","UK","Finland","USA","Fin ...

# %% [markdown]
# #**PREDICTIVE MODELLING**

# %% [markdown]
# ##Importing all necessary Libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from imblearn.over_sampling import SMOTE

# %% [markdown]
# ##Feature Selection

# %%
X = df[['Coffee_Intake','Caffeine_mg','Sleep_Hours', 'Sleep_Quality', 'BMI', 'Heart_Rate', 'Physical_Activity_Hours', 'Smoking']]
Y = df['Alcohol_Consumption']

# %%
(df==0).sum()
# Out:
# ID                            0
# Age                           0
# Gender                        0
# Country                       0
# Coffee_Intake               558
# Caffeine_mg                 528
# Sleep_Hours                   0
# Sleep_Quality                 0
# BMI                           0
# Heart_Rate                    0
# Stress_Level                  0
# Physical_Activity_Hours      27
# Health_Issues                 0
# Occupation                    0
# Smoking                    7996
# Alcohol_Consumption        6993
# dtype: int64

# %% [markdown]
# ##Train the Model

# %%
cols_with_zeros = [['Coffee_Intake', 'Caffeine_mg', 'Sleep_Hours', 'BMI', 'Heart_Rate','Physical_Activity_Hours', 'Smoking']]
for col in cols_with_zeros:
    df[col] = df[col].replace(0, df[col].median())

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

smote = SMOTE(random_state=42)
X_train_res, y_train_res = smote.fit_resample(X_train, Y_train)

# Step 3: Scale features
scaler = StandardScaler()
X_train_res = scaler.fit_transform(X_train_res)
X_test = scaler.transform(X_test)

# Step 4: Train model
model = LogisticRegression()
model.fit(X_train_res, y_train_res)
# Out:
# LogisticRegression()

# %% [markdown]
# ##Make Predictions

# %%
sample_data = [[5.0,400.0]] # Example data

# Convert sample data to a pandas DataFrame using original column names
sample_df = pd.DataFrame(sample_data, columns=X.columns)

# Apply the same scaling as used for the training data
sample_scaled = scaler.transform(sample_df)

# Make predictions on the scaled sample data
sample_predictions = model.predict(sample_scaled)

# Print the predictions
print("Predictions for sample data:", sample_predictions)
# Out:
# Predictions for sample data: [1]

# %%
from sklearn.metrics import accuracy_score
y_pred = model.predict(X_test)
accuracy = accuracy_score(Y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.482
